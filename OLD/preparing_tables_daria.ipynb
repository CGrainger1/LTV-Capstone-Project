# %% [markdown]
# # 1. Create a database connection 🔌🏦

# %%
import pandas as pd
from sqlalchemy import create_engine, types
from sqlalchemy import text # to be able to pass string

# %% [markdown]
# ### A ``connection string`` for postgresql could look like this:

# %% [markdown]
# ```python
# url = '<dialect>://<user>:<password>@<host>:<port>/<database>'
# ```

# %%
# Let's load values from the .env file
from dotenv import dotenv_values

config = dotenv_values()

# define variables for the login
pg_user = config['POSTGRES_USER']  # align the key label with your .env file !
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']

# %%
# Now building the URL with the values from the .env file

url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

# without specifying the schema default connection is to the schema `public`
# url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

# %% [markdown]
# ### With a connection string we can create an ``engine``:

# %%
pg_db
# Out:
# 'nf_da_270525'

# %%
engine = create_engine(url, echo=False)

# %% [markdown]
# The engine object manages connections to the database. It can be used to open new connections or to handle several connections at once.

# %%
# check your URL

engine.url # password is hidden
# Out:
# postgresql://dariabystrova:***@data-analytics-course-2.c8g8r1deus2v.eu-central-1.rds.amazonaws.com:5432/nf_da_270525

# %%
import pandas as pd
df_ltv = pd.read_csv('../LTV-Capstone-Project/Customer_LTV_Summary.csv')

# %%
from sqlalchemy import create_engine

# %%
df_ltv.to_sql('customer_ltv_summary', con=engine, if_exists='replace', index=False)
# Out:
# 153

# %%
df_ltv = pd.read_csv('../LTV-Capstone-Project/customer_roi.csv')

# %%
df_ltv.to_sql('customer_roi', con=engine, if_exists='replace', index=False)
# Out:
# 153

# %%
df_ltv_by_seasonal_activity = pd.read_csv('../LTV-Capstone-Project/ltv_by_seasonal_activity.csv')
df_ltv.to_sql('ltv_by_seasonal_activity', con=engine, if_exists='replace', index=False)
# Out:
# 153

# %%
df_ltv_by_coupon_quartile = pd.read_csv('../LTV-Capstone-Project/ltv_by_coupon_quartile.csv')
df_ltv.to_sql('ltv_by_coupon_quartile', con=engine, if_exists='replace', index=False)
# Out:
# 153

# %%
df_ltv_by_location_top10 = pd.read_csv('../LTV-Capstone-Project/ltv_by_location_top10.csv')
df_ltv.to_sql('ltv_by_location_top10', con=engine, if_exists='replace', index=False)
# Out:
# 153

# %%
df_ltv_by_gender = pd.read_csv('../LTV-Capstone-Project/ltv_by_gender.csv')
df_ltv.to_sql('ltv_by_gender', con=engine, if_exists='replace', index=False)
# Out:
# 153

# %%
df_ltv_by_tenure = pd.read_csv('../LTV-Capstone-Project/ltv_by_tenure.csv')
df_ltv.to_sql('ltv_by_tenure', con=engine, if_exists='replace', index=False)
# Out:
# 153

# %%
df_roi_by_location = pd.read_csv('../LTV-Capstone-Project/roi_by_location.csv')
df_ltv.to_sql('roi_by_location', con=engine, if_exists='replace', index=False)
# Out:
# 153

# %%
df_roi_by_gender = pd.read_csv('../LTV-Capstone-Project/roi_by_gender.csv')
df_ltv.to_sql('roi_by_gender', con=engine, if_exists='replace', index=False)
# Out:
# 153

# %% [markdown]
# ### Logging
#
# `sqlalchemy` and `psycopg2` translate python statements into SQL commands that a database server can understand.
# When creating the engine, you can set `echo=True` to print out all the raw SQL queries that are actually sent to the server in the background and are usually hidden from the Python programmer!

# %%
my_schema = 'team_3' # update it to your schema

with engine.begin() as conn: 
    result = conn.execute(text(f'SET search_path TO {my_schema};'))

# %%
df_online_sales = pd.read_csv('./Data/Online_Sales.csv')
df_customers = pd.read_excel('./Data/CustomersData.xlsx')
df_discount = pd.read_csv('./Data/Discount_Coupon.csv')
df_marketing = pd.read_csv('./Data/Marketing_Spend.csv')
df_tax = pd.read_excel('./Data/Tax_amount.xlsx')

# %%
my_schema = 'team_3'  

# Set schema and push DataFrames
df_online_sales.to_sql('online_sales', engine, schema=my_schema, if_exists='replace', index=False)
df_customers.to_sql('customers', engine, schema=my_schema, if_exists='replace', index=False)
df_discount.to_sql('discount_coupon', engine, schema=my_schema, if_exists='replace', index=False)
df_marketing.to_sql('marketing_spend', engine, schema=my_schema, if_exists='replace', index=False)
df_tax.to_sql('tax_amount', engine, schema=my_schema, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# InsufficientPrivilege                     Traceback (most recent call last)
# File c:\Users\dbyst\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1963, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962     if not evt_handled:
# -> 1963         self.dialect.do_execute(
#    1964             cursor, str_statement, effective_parameters, context
#    1965         )
#    1967 if self._has_events or self.engine._has_events:
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\sqlalchemy\engine\default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# InsufficientPrivilege: must be owner of table online_sales
#
#
# The above exception was the direct cause of the following exception:
#
# ...
